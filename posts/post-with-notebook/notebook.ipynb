# %% [raw]
# ---
# title: "Post With Notebbook"
# author: "Harlow Malloc"
# date: "2022-08-27"
# categories: [news, code, analysis]
# image: "image.jpg"
# ---

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,7])
